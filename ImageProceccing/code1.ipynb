# %%
'''
Lab-1: Color Space Conversion

Write a Python program to perform the following tasks:

Read an image.
Display the image resolution in the format: Resolution = Width × Height pixels.
Print the image color mode.
Convert the image into grayscale.
Display both the original image and the grayscale image.
Label each displayed image with an appropriate title.
Save the grayscale image.

Lab-2: Brightness adjustment of grayscale images

Write a Python program to perform the following tasks:

Read a grayscale image.
Increase the brightness of the image by multiplying each pixel value by a scaling factor S₁ = 1.5
Decrease the brightness of the image by multiplying each pixel value by a scaling factor S₂ = 0.3
Compare the original grayscale image with the brightness-adjusted images.
'''

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 2.5 MB/s  0:00:02 eta 0:00:01m
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PIL.Image as image
import matplotlib.pyplot as plt

# %%
# Read an image.
rgb_img = image.open("images/logo.jpg")

plt.imshow(rgb_img)
plt.show()

# %%
_mode = rgb_img.mode
print("Color mode is: ", _mode)
# Out:
# Color mode is:  RGB

# %%
print(rgb_img.size)
# Out:
# (600, 600)

# %%
width, height = rgb_img.size
print(f"Resolution = {width} x {height} pixels")
# Out:
# Resolution = 600 x 600 pixels

# %%
gray_img = rgb_img.convert('L')
plt.imshow(gray_img, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(15,8)) #inch
plt.subplot(1,2,1)
plt.imshow(rgb_img)
plt.title("original image")

plt.subplot(1,2,2)
plt.imshow(gray_img, cmap='gray')
plt.title("grayscale image")

plt.show()

# %%
gray_img.save("./images/output/grayscale.jpg")

# %%
import numpy as np

img = np.array(gray_img).astype('float32')
s1 = 1.5
s2 = 0.3

bright_img = img * s1
bright_img = np.clip(bright_img, 0, 255).astype('uint8')

dark_img = img * s2
dark_img = np.clip(dark_img, 0, 255).astype('uint8')


plt.figure(figsize=(15,8)) #inch
plt.subplot(1,3,1)
plt.imshow(gray_img, cmap='gray')
plt.title("grayscale image")

plt.subplot(1,3,2)
plt.imshow(bright_img, cmap='gray')
plt.title("brighter grayscale image")

plt.subplot(1,3,3)
plt.imshow(dark_img, cmap='gray')
plt.title("darker grayscale image")

plt.show()
